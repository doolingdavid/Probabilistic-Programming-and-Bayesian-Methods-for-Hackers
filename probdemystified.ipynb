# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import pytz
from pytz import common_timezones, all_timezones
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline
from datetime import datetime
#from __future__ import print_function

# %% [markdown]
# | **Experiment** | **Sample Space** |
# |:--------------:|:-------------------:|
# | Toss one coin | H, T |
# | Roll a die |  1, 2, 3, 4, 5, 6 |
# | Toss two coins  | HH ,HT, TH, TT |

# %% [markdown]
# | **Rank** | **Frequency** |
# |:--------------:|:------------------:|
# |Freshmen | 4 |
# | Sophomores | 8 |
# | Juniors | 6 |
# | Seniors | 7 |
# | TOTAL | 25 |

# %% [markdown]
# Another aspect of empirical probability is that if a large number of subjects (called a **sample**) is selected from a particular group (called a **population**), and the probability of a specific aattribute is computed, then when another subject is selected, we can say that the probability that this subject has the same attribute is the same as the original probabiility computed for the group. For example, a Gallup Poll of 1004 adults surveyed found that 17% of the subjects stated that they considered Abraham Lincoln to be the greatest President of the United States. Now if a subject is selected, the probability that he or she will say that Abraham Lincoln was the greatest president is also 17%.
#
# Several things should be explained here. First of all, the 1004 people constituted a sample selected from a larger group called the population. Second, the exact probability for the population can never be known unless every single member of the group is surveyed. This does not happen in these kinds of surveys since the population is usally very large. Hence, the 17% is only an estimate of the probability. However, if the sample is **representative** of the population, the estimate will usually be fairly close to the exact probability. Statisticians have a way of computing the accuracy (called the margin of error) for these situations. For the present, we shall just concentrate on the probability.

# %%
.17*1004
# Out:
# 170.68

# %%
N = 1004
n = 171

from scipy.stats import beta
alpha_prior = 1
beta_prior = 1

posterior_lincoln = beta(alpha_prior + n, beta_prior + N - n)

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
figsize(12.5, 4)
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
x = np.linspace(0,1, 5000)
plt.plot(x, posterior_lincoln.pdf(x), label='posterior of lincoln gallup poll')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title("Posterior distribution of the probability someone thinks \n Lincoln was the best President")
plt.legend()

# %%
print posterior_lincoln.interval(.95)
# Out:
# (0.14835147212017252, 0.19483575401800779)

# %% [markdown]
# Therefore we can say that we are 95% confident that the favorability rating is between 14.8% and 19.4% !

# %% [markdown]
# In a sample of 642 people over 25 years of age, 160 had a bachelor's degree. If a person over 25 years of age is selected, find the probability that the person has a bachelor's degree:

# %%
N = 642
n = 160

from scipy.stats import beta
alpha_prior = 1
beta_prior = 1

posterior_bachelor = beta(alpha_prior + n, beta_prior + N - n)

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
figsize(12.5, 4)
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
x = np.linspace(0,1, 5000)
plt.plot(x, posterior_bachelor.pdf(x), label='posterior of bachelor')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title("Posterior distribution of the probability of \n having a bachelors degree (>25)")
plt.legend()

# %%
print posterior_bachelor.mean()
# Out:
# 0.25

# %%
160./642
# Out:
# 0.24922118380062305

# %%
print posterior_bachelor.interval(.95)
# Out:
# (0.21733521798521727, 0.28413542722786789)

# %% [markdown]
# So we are 95% confident that the probability falls within (0.217, 0.284)

# %% [markdown]
# In the sample study of 642 people, it was found that 514 people have a high school diploma. If a person is selected at random, find the probability that the person does not have a high school diploma.

# %%
N = 642
n = 128

from scipy.stats import beta
alpha_prior = 1
beta_prior = 1

posterior_nohs = beta(alpha_prior + n, beta_prior + N - n)

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
figsize(12.5, 4)
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
x = np.linspace(0,1, 5000)
plt.plot(x, posterior_nohs.pdf(x), label='posterior of no high school')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title("Posterior distribution of the probability of \n not having a high school degree (>25)")
plt.legend()

# %%
print posterior_nohs.interval(.95)
# Out:
# (0.17032410697320538, 0.23205977808680389)

# %% [markdown]
# 1.
#
#
# | **Age** | **Number** |
# |:---------------:|:------------------:|
# | 20-29  | 18 |
# | 30-39  | 27 |
# | 40-49 | 36 |
# | 50-59 | 16 |
# | 60 or older | 3 |
# | Total | 100 |
#
#
# 1 (a) (36 + 16 + 3)/100 = 55/100
#
# (b) 45/100
#
# (c) 27/100
#
# (d) (36 + 16)/100 = 52/100

# %%
89./356
# Out:
# 0.25

# %%
len('mississippi')
# Out:
# 11

# %%
N = 180
n = 74

from scipy.stats import beta
alpha_prior = 1
beta_prior = 1

posterior_over64 = beta(alpha_prior + n, beta_prior + N - n)

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
figsize(12.5, 4)
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
x = np.linspace(0,1, 5000)
plt.plot(x, posterior_over64.pdf(x), label='posterior of being over 64')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title("Posterior distribution of the probability of \n being over 64")
plt.legend()

# %%
print posterior_over64.interval(.95)
# Out:
# (0.34177712961618872, 0.4842291702640622)

# %%
posterior_over64??

# %%
print 74./180
print posterior_over64.mean()
# Out:
# 0.411111111111
# 0.412087912088

# %%
.92 + .53 - .49
# Out:
# 0.9600000000000002

# %%
import math

# %%
math.factorial(6)
# Out:
# 720

# %%
from scipy.stats import binom
n, p = 3, 1./2
x = np.arange(binom.ppf(0.000, n, p), binom.ppf(1., n, p))
fig, ax = plt.subplots(1,1)
ax.plot(x, binom.pmf(x, n, p), 'bo', ms=8, label='binom pmf')
ax.vlines(x, 0, binom.pmf(x, n, p), colors='b', lw=5, alpha=0.5)

# %%
print binom.pmf(2, 3, 1./2)
# Out:
# 0.375

# %%
print binom.cdf(2, 3, 1./2)
# Out:
# 0.875

# %%
print binom.pmf(1, 3, 1./6)
# Out:
# 0.347222222222
